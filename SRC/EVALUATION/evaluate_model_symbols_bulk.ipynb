# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))

from SRC.LIBRARIES.new_utils import run_notebook_cell

# %env PRINT_OUT=True

model_name = 'GradExplosionTest_7'

symbol_s = [
    'ZECUSDT'
]

for symbol in symbol_s:
    run_notebook_cell(1, name='evaluate_model_one', rel_path='EVALUATION')
    run_notebook_cell(2, name='evaluate_model_one', rel_path='EVALUATION')
    run_notebook_cell(3, name='evaluate_model_one', rel_path='EVALUATION')
    run_notebook_cell(4, name='evaluate_model_one', rel_path='EVALUATION')
    run_notebook_cell(5, name='evaluate_model_one', rel_path='EVALUATION')
# Out:
# env: PRINT_OUT=True
# Running: [1] /Users/mac/CRYPTO_MACAQUES/SRC/EVALUATION/evaluate_model_one.ipynb
# Requirement already satisfied: zigzag in /Users/mac/.pyenv/versions/3.8.18/lib/python3.8/site-packages (0.3.2)
# Requirement already satisfied: numpy>=1.21.1 in /Users/mac/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from zigzag) (1.24.4)
# Requirement already satisfied: Cython<0.30,>=0.29 in /Users/mac/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from zigzag) (0.29.37)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# FETCHED: ZECUSDT | ['15M', '30M', '1H', '2H', '4H', '8H']
# FEATURIZED: ZECUSDT | ['15M', '30M', '1H', '2H', '4H', '8H']
# VALIDATED: ZECUSDT | utc_timestamp | ['15M', '30M', '1H', '2H', '4H', '8H']
# RETRIED GROUP: ['15M', '30M', '1H', '2H', '4H', '8H'] | ['15M_out', '15M_start', '15M_end', '30M_start', '30M_end', '1H_start', '1H_end', '2H_start', '2H_end', '4H_start', '4H_end', '8H_start', '8H_end']
# VALIDATED: GROUP | ['15M', '30M', '1H', '2H', '4H', '8H']
# Running: [2] /Users/mac/CRYPTO_MACAQUES/SRC/EVALUATION/evaluate_model_one.ipynb
# ZIGZAG & DIFF | ZIGZAGIZED: 0.0075 | DIFFERENTIFIED: 0.0075
# Running: [3] /Users/mac/CRYPTO_MACAQUES/SRC/EVALUATION/evaluate_model_one.ipynb
# Processed 0 groups: 2026-03-25 03:15:00+03:00, actual TPR: 0.007582277962211448, predicted TPR: 0
# Processed 500 groups: 2026-03-30 08:15:00+03:00, actual TPR: 0.02317543315460635, predicted TPR: 0
# Processed 896 groups: 2026-04-03 11:00:00+03:00, actual TPR: 0.0019312313699149097, predicted TPR: 0
# Running: [4] /Users/mac/CRYPTO_MACAQUES/SRC/EVALUATION/evaluate_model_one.ipynb
# Mean Squared Error: 0.00048525510132950726
# VALIDATED: ZECUSDT | kiev_timestamp | 15M | count = 1 | unique = [900] | first_kiev_timestamp = 03:15 25-03-26 | last_kiev_timestamp = 11:00 03-04-26
# Running: [5] /Users/mac/CRYPTO_MACAQUES/SRC/EVALUATION/evaluate_model_one.ipynb
